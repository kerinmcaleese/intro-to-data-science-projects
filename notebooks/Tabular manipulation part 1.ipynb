# %%
# import pandas library
import pandas as pd

# %%
import pandas as pd
us_babies=pd.read_csv("/Users/kerinmcaleese/Exercise Files/us_baby_names.csv")

# %%
us_babies
# Out:
#               Id       Name  Year Gender  Count
# 0              1       Mary  1880      F   7065
# 1              2       Anna  1880      F   2604
# 2              3       Emma  1880      F   2003
# 3              4  Elizabeth  1880      F   1939
# 4              5     Minnie  1880      F   1746
# ...          ...        ...   ...    ...    ...
# 1825428  1825429     Zykeem  2014      M      5
# 1825429  1825430     Zymeer  2014      M      5
# 1825430  1825431    Zymiere  2014      M      5
# 1825431  1825432      Zyran  2014      M      5
# 1825432  1825433      Zyrin  2014      M      5
#
# [1825433 rows x 5 columns]

# %%
us_babies['Year']
# Out:
# 0          1880
# 1          1880
# 2          1880
# 3          1880
# 4          1880
#            ...
# 1825428    2014
# 1825429    2014
# 1825430    2014
# 1825431    2014
# 1825432    2014
# Name: Year, Length: 1825433, dtype: int64

# %%
us_babies['Year'] == 2014
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1825428     True
# 1825429     True
# 1825430     True
# 1825431     True
# 1825432     True
# Name: Year, Length: 1825433, dtype: bool

# %%
us_babies2014=us_babies.loc[us_babies['Year'] == 2014, :]

# %%
us_babies2014
# Out:
#               Id      Name  Year Gender  Count
# 1792389  1792390      Emma  2014      F  20799
# 1792390  1792391    Olivia  2014      F  19674
# 1792391  1792392    Sophia  2014      F  18490
# 1792392  1792393  Isabella  2014      F  16950
# 1792393  1792394       Ava  2014      F  15586
# ...          ...       ...   ...    ...    ...
# 1825428  1825429    Zykeem  2014      M      5
# 1825429  1825430    Zymeer  2014      M      5
# 1825430  1825431   Zymiere  2014      M      5
# 1825431  1825432     Zyran  2014      M      5
# 1825432  1825433     Zyrin  2014      M      5
#
# [33044 rows x 5 columns]

# %%
sorted_us_2014=us_babies2014.sort_values('Count',ascending=False)

# %%
sorted_us_2014
# Out:
#               Id     Name  Year Gender  Count
# 1792389  1792390     Emma  2014      F  20799
# 1792390  1792391   Olivia  2014      F  19674
# 1811456  1811457     Noah  2014      M  19144
# 1792391  1792392   Sophia  2014      F  18490
# 1811457  1811458     Liam  2014      M  18342
# ...          ...      ...   ...    ...    ...
# 1825424  1825425  Zmarion  2014      M      5
# 1825423  1825424   Ziyang  2014      M      5
# 1825422  1825423    Ziyah  2014      M      5
# 1825421  1825422    Zivon  2014      M      5
# 1825420  1825421    Zirui  2014      M      5
#
# [33044 rows x 5 columns]

# %%
sorted_us_2014.iloc[0:5]
# Out:
#               Id    Name  Year Gender  Count
# 1792389  1792390    Emma  2014      F  20799
# 1792390  1792391  Olivia  2014      F  19674
# 1811456  1811457    Noah  2014      M  19144
# 1792391  1792392  Sophia  2014      F  18490
# 1811457  1811458    Liam  2014      M  18342

# %%
states_babies=pd.read_csv("state_baby_names.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 states_babies=pd.read_csv("state_baby_names.csv")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import pandas as pd
states_babies = pd.read_csv("/Users/kerinmcaleese/Desktop/state_baby_names.csv")
states_babies.head()
# Out:
#    Id      Name  Year Gender State  Count
# 0   1      Mary  1910      F    AK     14
# 1   2     Annie  1910      F    AK     12
# 2   3      Anna  1910      F    AK     10
# 3   4  Margaret  1910      F    AK      8
# 4   5     Helen  1910      F    AK      7

# %%
states_babies_2014 = states_babies.loc[states_babies["Year"] == 2014, :]

# %%
states_babies_2014
# Out:
#               Id      Name  Year Gender State  Count
# 13522      13523      Emma  2014      F    AK     50
# 13523      13524    Olivia  2014      F    AK     47
# 13524      13525    Sophia  2014      F    AK     43
# 13525      13526    Aurora  2014      F    AK     35
# 13526      13527  Isabella  2014      F    AK     33
# ...          ...       ...   ...    ...   ...    ...
# 5647421  5647422      Seth  2014      M    WY      5
# 5647422  5647423   Spencer  2014      M    WY      5
# 5647423  5647424      Tyce  2014      M    WY      5
# 5647424  5647425    Victor  2014      M    WY      5
# 5647425  5647426    Waylon  2014      M    WY      5
#
# [94148 rows x 6 columns]

# %%
ca_babies_2014 = states_babies_2014.loc[states_babies_2014["State"] == "CA"]

# %%
ca_babies_2014
# Out:
#             Id      Name  Year Gender State  Count
# 561495  561496    Sophia  2014      F    CA   3162
# 561496  561497  Isabella  2014      F    CA   2705
# 561497  561498      Emma  2014      F    CA   2662
# 561498  561499       Mia  2014      F    CA   2627
# 561499  561500    Olivia  2014      F    CA   2407
# ...        ...       ...   ...    ...   ...    ...
# 710225  710226    Zakary  2014      M    CA      5
# 710226  710227   Zealand  2014      M    CA      5
# 710227  710228      Ziad  2014      M    CA      5
# 710228  710229    Zidane  2014      M    CA      5
# 710229  710230     Ziyad  2014      M    CA      5
#
# [6903 rows x 6 columns]

# %%
sorted_ca_2014 = ca_babies_2014.sort_values("Count", ascending = False)

# %%
sorted_ca_2014
# Out:
#             Id      Name  Year Gender State  Count
# 561495  561496    Sophia  2014      F    CA   3162
# 707311  707312      Noah  2014      M    CA   2761
# 561496  561497  Isabella  2014      F    CA   2705
# 707312  707313     Jacob  2014      M    CA   2692
# 561497  561498      Emma  2014      F    CA   2662
# ...        ...       ...   ...    ...   ...    ...
# 710215  710216    Yamato  2014      M    CA      5
# 710214  710215     Xaden  2014      M    CA      5
# 710213  710214      Xabi  2014      M    CA      5
# 710212  710213      Wren  2014      M    CA      5
# 710211  710212    Westyn  2014      M    CA      5
#
# [6903 rows x 6 columns]

# %%
sorted_ca_2014.iloc[0:5]
# Out:
#             Id      Name  Year Gender State  Count
# 561495  561496    Sophia  2014      F    CA   3162
# 707311  707312      Noah  2014      M    CA   2761
# 561496  561497  Isabella  2014      F    CA   2705
# 707312  707313     Jacob  2014      M    CA   2692
# 561497  561498      Emma  2014      F    CA   2662

# %%
ca_babies = states_babies.loc[states_babies['State'] == 'CA', :]

# %%
ca_babies
# Out:
#             Id      Name  Year Gender State  Count
# 356017  356018      Mary  1910      F    CA    295
# 356018  356019     Helen  1910      F    CA    239
# 356019  356020   Dorothy  1910      F    CA    220
# 356020  356021  Margaret  1910      F    CA    163
# 356021  356022   Frances  1910      F    CA    134
# ...        ...       ...   ...    ...   ...    ...
# 710225  710226    Zakary  2014      M    CA      5
# 710226  710227   Zealand  2014      M    CA      5
# 710227  710228      Ziad  2014      M    CA      5
# 710228  710229    Zidane  2014      M    CA      5
# 710229  710230     Ziyad  2014      M    CA      5
#
# [354213 rows x 6 columns]

# %%
def popular(s):
    """Receives s, a Pandass Series, containing baby names in order of highest count to lowest count.
    Returns the most popular name in s."""
    return s.iloc[0]

# %%
ca_grouped = ca_babies.sort_values('Count', ascending = False).groupby(['Year', 'Gender']).agg(popular)

# %%
ca_grouped
# Out:
#                  Id    Name State  Count
# Year Gender
# 1910 F       356018    Mary    CA    295
#      M       565480    John    CA    237
# 1911 F       356251    Mary    CA    390
#      M       565610    John    CA    214
# 1912 F       356502    Mary    CA    534
# ...             ...     ...   ...    ...
# 2012 M       701517   Jacob    CA   2971
# 2013 F       557545  Sophia    CA   3451
#      M       704421   Jacob    CA   2879
# 2014 F       561496  Sophia    CA   3162
#      M       707312    Noah    CA   2761
#
# [210 rows x 4 columns]

# %%
us_ker = us_babies.loc[us_babies['Name'] == 'Kerin', :]

# %%
us_ker
# Out:
#               Id   Name  Year Gender  Count
# 326029    326030  Kerin  1935      F      5
# 332335    332336  Kerin  1936      F     18
# 342243    342244  Kerin  1937      F     10
# 352021    352022  Kerin  1938      F      7
# 388711    388712  Kerin  1942      F      6
# ...          ...    ...   ...    ...    ...
# 1562787  1562788  Kerin  2007      F     12
# 1637372  1637373  Kerin  2009      F      7
# 1676020  1676021  Kerin  2010      F      5
# 1709816  1709817  Kerin  2011      F      5
# 1777085  1777086  Kerin  2013      F      5
#
# [101 rows x 5 columns]

# %%
us_ker.plot.barh(x = 'Year', y = 'Count')
# Out:
# <Axes: ylabel='Year'>
